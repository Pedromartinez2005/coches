# %%
import pandas as pd
import matplotlib.pyplot as plt
coches_francia_df= pd.read_csv('../data/processed/cars_france.csv')
coches_holanda_df= pd.read_csv('../data/processed/cars_netherlands.csv')
coches_alemania_df= pd.read_csv('../data/processed/cars_germany.csv')
coches_españa_df= pd.read_csv('../data/processed/cars_spain.csv' )

# %% [markdown]
# # Analisis coches España

# %% [markdown]
# - Seat

# %%
colores = { 2021: (102/255, 153/255, 255/255) ,2022: (102/255, 255/255, 178/255), 2023: (255/255, 204/255, 102/255), 2024:(255/255, 102/255, 102/255)  }
#SEAT
seat_espña=coches_españa_df[coches_españa_df['marca'] == 'SEAT']
seat_espña=seat_espña.groupby('año').count()['marca'].rename('')
seat_espña
plt.figure(figsize=(20,20))
ax1=plt.subplot(2,3,1)
seat_espña.plot(kind='pie',ax=ax1,autopct='%.2f',colors=[colores.get(year) for year in seat_espña.index])
plt.title('Seat')

#OPEL
opel_españa=coches_españa_df[coches_españa_df['marca'] == 'OPEL']
opel_españa=opel_españa.groupby('año').count()['marca'].rename('')
ax2=plt.subplot(2,3,2)
opel_españa.plot(kind='pie',ax=ax2,autopct='%.2f',colors=[colores.get(year) for year in opel_españa.index])
plt.title('Opel')

#RENAULT
renault_españa=coches_españa_df[coches_españa_df['marca'] == 'RENAULT']
renault_españa=renault_españa.groupby('año').count()['marca'].rename('')
ax3=plt.subplot(2,3,3)
renault_españa.plot(kind='pie',ax=ax3,autopct='%.2f',colors=[colores.get(year) for year in renault_españa.index])
plt.title('Renault')

#HYUNDAI
hyundai_españa=coches_españa_df[coches_españa_df['marca'] == 'HYUNDAI']
hyundai_españa=hyundai_españa.groupby('año').count()['marca'].rename('')
ax4=plt.subplot(2,3,4)
hyundai_españa.plot(kind='pie',ax=ax4,autopct='%.2f',colors=[colores.get(year) for year in hyundai_españa.index])
plt.title('Hyundai')

#VOLSKWAGEM
volsk_españa=coches_españa_df[coches_españa_df['marca'] == 'VOLKSWAGEN']
volsk_españa=volsk_españa.groupby('año').count()['marca'].rename('')
ax5=plt.subplot(2,3,5)
volsk_españa.plot(kind='pie',ax=ax5,autopct='%.2f',colors=[colores.get(year) for year in volsk_españa.index])
plt.title('Volswagen')
#TOYOTA
toyota_españa=coches_españa_df[coches_españa_df['marca'] == 'TOYOTA']
toyota_españa=toyota_españa.groupby('año').count()['marca'].rename('')
ax6=plt.subplot(2,3,6)
toyota_españa.plot(kind='pie',ax=ax6,autopct='%.2f',colors=[colores.get(year) for year in toyota_españa.index])
plt.title('Toyota')
# Out:
# Text(0.5, 1.0, 'Toyota')

# %% [markdown]
# # Analisis Coches Alemania

# %%
colores = { 2021: (102/255, 153/255, 255/255) ,2022: (102/255, 255/255, 178/255), 2023: (255/255, 204/255, 102/255), 2024:(255/255, 102/255, 102/255)  }

# SEAT
seat_alemania = coches_alemania_df[coches_alemania_df['marca'] == 'SEAT']
seat_alemania = seat_alemania.groupby('año').count()['marca'].rename('')
plt.figure(figsize=(23, 20))
ax1 = plt.subplot(2, 3, 1)
seat_alemania.plot(kind='pie', ax=ax1, autopct='%.2f',colors=[colores.get(year) for year in seat_alemania.index])
plt.title('Seat')

# OPEL
opel_alemania = coches_alemania_df[coches_alemania_df['marca'] == 'OPEL']
opel_alemania = opel_alemania.groupby('año').count()['marca'].rename('')
ax2 = plt.subplot(2, 3, 2)
opel_alemania.plot(kind='pie', ax=ax2, autopct='%.2f',colors=[colores.get(year) for year in opel_alemania.index])
plt.title('Opel')

# RENAULT
renault_alemania = coches_alemania_df[coches_alemania_df['marca'] == 'RENAULT']
renault_alemania = renault_alemania.groupby('año').count()['marca'].rename('')
ax3 = plt.subplot(2, 3, 3)
renault_alemania.plot(kind='pie', ax=ax3, autopct='%.2f',colors=[colores.get(year) for year in renault_alemania.index])
plt.title('Renault')

# HYUNDAI
hyundia_alemania = coches_alemania_df[coches_alemania_df['marca'] == 'HYUNDAI']
hyundia_alemania = hyundia_alemania.groupby('año').count()['marca'].rename('')
ax4 = plt.subplot(2, 3, 4)
hyundia_alemania.plot(kind='pie', ax=ax4, autopct='%.2f',colors=[colores.get(year) for year in hyundia_alemania.index])
plt.title('Hyundai')

# VOLKSWAGEN
volsk_alemania = coches_alemania_df[coches_alemania_df['marca'] == 'VOLKSWAGEN']
volsk_alemania = volsk_alemania.groupby('año').count()['marca'].rename('')
ax5 = plt.subplot(2, 3, 5)
volsk_alemania.plot(kind='pie', ax=ax5, autopct='%.2f',colors=[colores.get(year) for year in volsk_alemania.index])
plt.title('Volkswagen')

# TOYOTA
toyota_alemania = coches_alemania_df[coches_alemania_df['marca'] == 'TOYOTA']
toyota_alemania = toyota_alemania.groupby('año').count()['marca'].rename('')
ax6 = plt.subplot(2, 3, 6)
toyota_alemania.plot(kind='pie', ax=ax6, autopct='%.2f',colors=[colores.get(year) for year in toyota_alemania.index])
plt.title('Toyota')
# Out:
# Text(0.5, 1.0, 'Toyota')

# %% [markdown]
# # Analisis coches Holanda

# %%
colores = { 2021: (102/255, 153/255, 255/255) ,2022: (102/255, 255/255, 178/255), 2023: (255/255, 204/255, 102/255), 2024:(255/255, 102/255, 102/255)  }
# SEAT
seat_holanda = coches_holanda_df[coches_holanda_df['marca'] == 'SEAT']
seat_holanda = seat_holanda.groupby('año').count()['marca'].rename('')
seat_holanda
plt.figure(figsize=(23, 20))
ax1 = plt.subplot(2, 3, 1)
seat_holanda.plot(kind='pie', ax=ax1, autopct='%.2f',colors=[colores.get(year) for year in seat_holanda.index])
plt.title('Seat')

# OPEL
opel_holanda = coches_holanda_df[coches_holanda_df['marca'] == 'OPEL']
opel_holanda = opel_holanda.groupby('año').count()['marca'].rename('')
ax2 = plt.subplot(2, 3, 2)
opel_holanda.plot(kind='pie', ax=ax2, autopct='%.2f',colors=[colores.get(year) for year in opel_holanda.index])
plt.title('Opel')

# RENAULT
renault_holanda = coches_holanda_df[coches_holanda_df['marca'] == 'RENAULT']
renault_holanda = renault_holanda.groupby('año').count()['marca'].rename('')
ax3 = plt.subplot(2, 3, 3)
renault_holanda.plot(kind='pie', ax=ax3, autopct='%.2f',colors=[colores.get(year) for year in renault_holanda.index])
plt.title('Renault')

# HYUNDAI
hyundia_holanda = coches_holanda_df[coches_holanda_df['marca'] == 'HYUNDAI']
hyundia_holanda = hyundia_holanda.groupby('año').count()['marca'].rename('')
ax4 = plt.subplot(2, 3, 4)
hyundia_holanda.plot(kind='pie', ax=ax4, autopct='%.2f',colors=[colores.get(year) for year in hyundia_holanda.index])
plt.title('Hyundai')

# VOLKSWAGEN
volsk_holanda = coches_holanda_df[coches_holanda_df['marca'] == 'VOLKSWAGEN']
volsk_holanda = volsk_holanda.groupby('año').count()['marca'].rename('')
ax5 = plt.subplot(2, 3, 5)
volsk_holanda.plot(kind='pie', ax=ax5, autopct='%.2f',colors=[colores.get(year) for year in volsk_holanda.index])
plt.title('Volkswagen')

# TOYOTA
toyota_holanda = coches_holanda_df[coches_holanda_df['marca'] == 'TOYOTA']
toyota_holanda = toyota_holanda.groupby('año').count()['marca'].rename('')
ax6 = plt.subplot(2, 3, 6)
toyota_holanda.plot(kind='pie', ax=ax6, autopct='%.2f',colors=[colores.get(year) for year in toyota_holanda.index])
plt.title('Toyota')
# Out:
# Text(0.5, 1.0, 'Toyota')

# %% [markdown]
# # Analisis coches Francia

# %%
colores = { 2021: (102/255, 153/255, 255/255) ,2022: (102/255, 255/255, 178/255), 2023: (255/255, 204/255, 102/255), 2024:(255/255, 102/255, 102/255)  }
# SEAT
seat_francia = coches_francia_df[coches_francia_df['marca'] == 'SEAT']
seat_francia = seat_francia.groupby('año').count()['marca'].rename('')
plt.figure(figsize=(23, 20))
ax1 = plt.subplot(2, 3, 1)
seat_francia.plot(kind='pie', ax=ax1, autopct='%.2f',colors=[colores.get(year) for year in seat_francia.index])
plt.title('Seat')

# OPEL
opel_francia = coches_francia_df[coches_francia_df['marca'] == 'OPEL']
opel_francia = opel_francia.groupby('año').count()['marca'].rename('')
ax2 = plt.subplot(2, 3, 2)
opel_francia.plot(kind='pie', ax=ax2, autopct='%.2f',colors=[colores.get(year) for year in opel_francia.index])
plt.title('Opel')

# RENAULT
renault_francia = coches_francia_df[coches_francia_df['marca'] == 'RENAULT']
renault_francia = renault_francia.groupby('año').count()['marca'].rename('')
ax3 = plt.subplot(2, 3, 3)
renault_francia.plot(kind='pie', ax=ax3, autopct='%.2f',colors=[colores.get(year) for year in renault_francia.index])
plt.title('Renault')

# HYUNDAI
hyundia_francia = coches_francia_df[coches_francia_df['marca'] == 'HYUNDAI']
hyundia_francia = hyundia_francia.groupby('año').count()['marca'].rename('')
ax4 = plt.subplot(2, 3, 4)
hyundia_francia.plot(kind='pie', ax=ax4, autopct='%.2f',colors=[colores.get(year) for year in hyundia_francia.index])
plt.title('Hyundai')

# VOLKSWAGEN
volsk_francia = coches_francia_df[coches_francia_df['marca'] == 'VOLKSWAGEN']
volsk_francia = volsk_francia.groupby('año').count()['marca'].rename('')
ax5 = plt.subplot(2, 3, 5)
volsk_francia.plot(kind='pie', ax=ax5, autopct='%.2f',colors=[colores.get(year) for year in volsk_francia.index])
plt.title('Volkswagen')

# TOYOTA
toyota_francia = coches_francia_df[coches_francia_df['marca'] == 'TOYOTA']
toyota_francia = toyota_francia.groupby('año').count()['marca'].rename('')
ax6 = plt.subplot(2, 3, 6)
toyota_francia.plot(kind='pie', ax=ax6, autopct='%.2f',colors=[colores.get(year) for year in toyota_francia.index])
plt.title('Toyota')

plt.show()
